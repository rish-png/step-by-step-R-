# %%
library(datasets)
head(lynx) # only onne variable so single line of start 6 vals
# Out:
# [1]  269  321  585  871 1475 2821

# %%
hist(lynx, breaks=14, freq=F, # Freq False changes to density
     col ='thistle1',
    main='Hist of annual Canadian Lynx trapping from 1821-1934',
    xlab='Number of lynx trapped')
# adding a curve to this histogram giving idea what a normal curve would have
# looked like if it had the same mean and standev as the histogram
curve(dnorm(x, mean= mean(lynx), sd=sd(lynx)), add=T, lwd=2, col='thistle4')
# add = T overlays on the same graph
rug(lynx, lwd=2, col='gray')
# Out:
# Plot with title “Hist of annual Canadian Lynx trapping from 1821-1934”
